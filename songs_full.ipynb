# %%
import pandas as pd
import numpy as np
# To see all columns when dataframe is displayed.
pd.set_option("max_columns", None)

# %%
# Read tracks.csv.
tracks = pd.read_csv('tracks3.csv')
tracks.shape
# Out:
# (106574, 53)

# %%
tracks
# Out:
#         track_id  album_comments   album_date_created  album_date_released  \
# 0              2               0  2008-11-26 01:44:45  2009-01-05 00:00:00
# 1              3               0  2008-11-26 01:44:45  2009-01-05 00:00:00
# 2              5               0  2008-11-26 01:44:45  2009-01-05 00:00:00
# 3             10               0  2008-11-26 01:45:08  2008-02-06 00:00:00
# 4             20               0  2008-11-26 01:45:05  2009-01-06 00:00:00
# 5             26               0  2008-11-26 01:45:05  2009-01-06 00:00:00
# 6             30               0  2008-11-26 01:45:05  2009-01-06 00:00:00
# 7             46               0  2008-11-26 01:45:05  2009-01-06 00:00:00
# 8             48               0  2008-11-26 01:45:05  2009-01-06 00:00:00
# 9            134               0  2008-11-26 01:44:45  2009-01-05 00:00:00
# 10           135               1  2008-11-26 01:49:19  2009-01-07 00:00:00
# ...

# %%
# Select relevant columns.
col_list = ['track_id', 'album_date_created', 'album_title', 'artist_location', 'artist_name', 'track_genres_all', 'track_language_code', 'track_title']

# %%
tracks = tracks[col_list]

# %%
tracks
# Out:
#         track_id   album_date_created  \
# 0              2  2008-11-26 01:44:45
# 1              3  2008-11-26 01:44:45
# 2              5  2008-11-26 01:44:45
# 3             10  2008-11-26 01:45:08
# 4             20  2008-11-26 01:45:05
# 5             26  2008-11-26 01:45:05
# 6             30  2008-11-26 01:45:05
# 7             46  2008-11-26 01:45:05
# 8             48  2008-11-26 01:45:05
# 9            134  2008-11-26 01:44:45
# 10           135  2008-11-26 01:49:19
# 11           136  2008-11-26 01:49:19
# 12           137  2008-11-26 01:49:35
# 13           138  2008-11-26 01:49:35
# 14           139  2008-11-26 01:49:57
# 15           140  2008-11-26 01:49:59
# 16           141  2008-11-26 01:49:57
# 17           142  2008-11-26 01:50:03
# 18           144  2008-11-26 01:50:07
# 19           145  2008-11-26 01:50:07
# 20           146  2008-11-26 01:50:13
# 21           147  2008-11-26 01:50:13
# 22           148  2008-11-26 01:50:19
# ...

# %%
# Delete NaN values at this point. 
tracks = tracks[~tracks[['album_date_created', 'album_title', 'artist_name', 'track_title']].isnull().any(axis=1)]
tracks.shape
# Out:
# (103044, 8)

# %%
tracks
# Out:
#         track_id   album_date_created  \
# 0              2  2008-11-26 01:44:45
# 1              3  2008-11-26 01:44:45
# 2              5  2008-11-26 01:44:45
# 3             10  2008-11-26 01:45:08
# 4             20  2008-11-26 01:45:05
# 5             26  2008-11-26 01:45:05
# 6             30  2008-11-26 01:45:05
# 7             46  2008-11-26 01:45:05
# 8             48  2008-11-26 01:45:05
# 9            134  2008-11-26 01:44:45
# 10           135  2008-11-26 01:49:19
# 11           136  2008-11-26 01:49:19
# 12           137  2008-11-26 01:49:35
# 13           138  2008-11-26 01:49:35
# 14           139  2008-11-26 01:49:57
# 15           140  2008-11-26 01:49:59
# 16           141  2008-11-26 01:49:57
# 17           142  2008-11-26 01:50:03
# 18           144  2008-11-26 01:50:07
# 19           145  2008-11-26 01:50:07
# 20           146  2008-11-26 01:50:13
# 21           147  2008-11-26 01:50:13
# 22           148  2008-11-26 01:50:19
# ...

# %%
# Read views.csv.
yt_views = pd.read_csv('views.csv')
yt_views.shape
# Out:
# (103044, 1)

# %%
yt_views
# Out:
#          yt_views
# 0             754
# 1            1936
# 2           87392
# 3          193927
# 4          100282
# 5          201490
# 6        16960371
# 7           83059
# 8            4452
# 9        88747862
# 10             25
# 11            615
# 12         223288
# 13        1140719
# 14             83
# 15           1835
# 16            220
# 17           1911
# 18           2516
# 19            995
# 20            917
# 21            917
# 22            617
# 23             -1
# 24            177
# 25      625096451
# 26         328439
# 27          28515
# 28          55795
# 29             54
# ...           ...
# 103014    2972544
# 103015        114
# 103016       9865
# 103017        147
# 103018      94044
# 103019        784
# 103020         26
# 103021        430
# 103022         51
# 103023          0
# 103024          0
# 103025         11
# 103026         48
# 103027          2
# 103028          5
# 103029          8
# 103030          1
# 103031       6969
# ...

# %%
# We needed to loop through the dataframes because some indices was deleted and
# by simply adding the column is merging by the indices. It would've been
# filled with NaNs all the rows after about 103.000.
tracks['yt_views'] = np.nan
for i in range(len(yt_views)):
    tracks.iloc[i, 7] = yt_views.iloc[i, 0]

tracks.shape
# Out:
# (103044, 11)

# %%
tracks
# Out:
#         level_0   index  track_id   album_date_created  \
# 0             0       0         2  2008-11-26 01:44:45
# 1             1       1         3  2008-11-26 01:44:45
# 2             2       2         5  2008-11-26 01:44:45
# 3             3       3        10  2008-11-26 01:45:08
# 4             4       4        20  2008-11-26 01:45:05
# 5             5       5        26  2008-11-26 01:45:05
# 6             6       6        30  2008-11-26 01:45:05
# 7             7       7        46  2008-11-26 01:45:05
# 8             8       8        48  2008-11-26 01:45:05
# 9             9       9       134  2008-11-26 01:44:45
# 10           10      10       135  2008-11-26 01:49:19
# 11           11      11       136  2008-11-26 01:49:19
# 12           12      12       137  2008-11-26 01:49:35
# 13           13      13       138  2008-11-26 01:49:35
# 14           14      14       139  2008-11-26 01:49:57
# 15           15      15       140  2008-11-26 01:49:59
# ...

# %%
#tracks[tracks['track_language_code'].apply(lambda x: False if x == 'en' else True)]

# %%
#tracks.iloc[103043,4]

# %%
yt_views.iloc[2]

# %%
for i in range(5):
    print('i: ',i)
    print('ti: ', type(i))
